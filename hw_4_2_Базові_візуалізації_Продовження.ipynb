# %% [markdown]
# # Домашнє завдання №1 до модуля 4: Базові візуалізації даних. Продовження

# %% [markdown]
# В цьому домашньому завданні потренуємо створення кількох панелей на одній фігурі для відпрацювання створення складніших візуалізацій з Matplotlib, а також підписи до графіків і створення легенди.
#
# ### Завдання: Візуалізація функцій експоненти, логарифму, і модифікованої синусоїди
#
# **Мета:** Створити фігуру з трьома панелями: на першій показати графік експоненціальної функції, на другій - логарифмічну функцію, а на третій - модифіковану синусоїду.
#
# 1. Імпортуйте необхідні бібліотеки:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Використовуючи фукнціонал `numpy` створіть масив `x` з 400 точок в діапазоні між -2 та 2 і масив `x_positive` в діапазоні між 0.1 і 2 також з 400 точок. Другий масив в нас буде для логарифмічної функції, перший з більш широким діапазоном - для інших функцій.

# %%
x = np.linspace (-2, 2, 400)

# %%
x
# Out:
# array([-2.        , -1.98997494, -1.97994987, -1.96992481, -1.95989975,
#        -1.94987469, -1.93984962, -1.92982456, -1.9197995 , -1.90977444,
#        -1.89974937, -1.88972431, -1.87969925, -1.86967419, -1.85964912,
#        -1.84962406, -1.839599  , -1.82957393, -1.81954887, -1.80952381,
#        -1.79949875, -1.78947368, -1.77944862, -1.76942356, -1.7593985 ,
#        -1.74937343, -1.73934837, -1.72932331, -1.71929825, -1.70927318,
#        -1.69924812, -1.68922306, -1.67919799, -1.66917293, -1.65914787,
#        -1.64912281, -1.63909774, -1.62907268, -1.61904762, -1.60902256,
#        -1.59899749, -1.58897243, -1.57894737, -1.56892231, -1.55889724,
#        -1.54887218, -1.53884712, -1.52882206, -1.51879699, -1.50877193,
#        -1.49874687, -1.4887218 , -1.47869674, -1.46867168, -1.45864662,
#        -1.44862155, -1.43859649, -1.42857143, -1.41854637, -1.4085213 ,
#        -1.39849624, -1.38847118, -1.37844612, -1.36842105, -1.35839599,
#        -1.34837093, -1.33834586, -1.3283208 , -1.31829574, -1.30827068,
#        -1.29824561, -1.28822055, -1.27819549, -1.26817043, -1.25814536,
#        -1.2481203 , -1.23809524, -1.22807018, -1.21804511, -1.20802005,
#        -1.19799499, -1.18796992, -1.17794486, -1.1679198 , -1.15789474,
#        -1.14786967, -1.13784461, -1.12781955, -1.11779449, -1.10776942,
#        -1.09774436, -1.0877193 , -1.07769424, -1.06766917, -1.05764411,
#        -1.04761905, -1.03759398, -1.02756892, -1.01754386, -1.0075188 ,
#        -0.99749373, -0.98746867, -0.97744361, -0.96741855, -0.95739348,
#        -0.94736842, -0.93734336, -0.9273183 , -0.91729323, -0.90726817,
#        -0.89724311, -0.88721805, -0.87719298, -0.86716792, -0.85714286,
#        -0.84711779, -0.83709273, -0.82706767, -0.81704261, -0.80701754,
#        -0.79699248, -0.78696742, -0.77694236, -0.76691729, -0.75689223,
#        -0.74686717, -0.73684211, -0.72681704, -0.71679198, -0.70676692,
#        1.5047619 , 1.50952381, 1.51428571, 1.51904762, 1.52380952,
#        1.52857143, 1.53333333, 1.53809524, 1.54285714, 1.54761905,
#        1.55238095, 1.55714286, 1.56190476, 1.56666667, 1.57142857,
#        1.57619048, 1.58095238, 1.58571429, 1.59047619, 1.5952381 ,
#        1.6       , 1.6047619 , 1.60952381, 1.61428571, 1.61904762,
#        1.62380952, 1.62857143, 1.63333333, 1.63809524, 1.64285714,
#        1.64761905, 1.65238095, 1.65714286, 1.66190476, 1.66666667,
#        1.67142857, 1.67619048, 1.68095238, 1.68571429, 1.69047619,
#        1.6952381 , 1.7       , 1.7047619 , 1.70952381, 1.71428571,
#        1.71904762, 1.72380952, 1.72857143, 1.73333333, 1.73809524,
#        1.74285714, 1.74761905, 1.75238095, 1.75714286, 1.76190476,
#        1.76666667, 1.77142857, 1.77619048, 1.78095238, 1.78571429,
#        1.79047619, 1.7952381 , 1.8       , 1.8047619 , 1.80952381,
#        1.81428571, 1.81904762, 1.82380952, 1.82857143, 1.83333333,
#        1.83809524, 1.84285714, 1.84761905, 1.85238095, 1.85714286,
#        1.86190476, 1.86666667, 1.87142857, 1.87619048, 1.88095238,
#        1.88571429, 1.89047619, 1.8952381 , 1.9       , 1.9047619 ,
#        1.90952381, 1.91428571, 1.91904762, 1.92380952, 1.92857143,
#        1.93333333, 1.93809524, 1.94285714, 1.94761905, 1.95238095,
#        1.95714286, 1.96190476, 1.96666667, 1.97142857, 1.97619048,
#        1.98095238, 1.98571429, 1.99047619, 1.9952381 , 2.        ])

# %% [markdown]
# 3. Тут маємо кілька кроків.
#
#   3.1. Ініціалізуйте фігуру Matplotlib з розміром, достатнім для трьох панелей (рекомендую спробувати експериментально виявити добрий розмір).
#   3.2. На першій панелі візуалізуйте експоненціальну функцію `y = e^x`. Використовуйте відповідну змінну `x`.
#   3.2. На другій панелі покажіть логарифмічну функцію `y = ln(x)`.
#   3.4. На третій панелі покажіть модифіковану синусоїду `y = sin(x) + x`.
#
#   Відобразіть графік.

# %%
plt.figure (figsize = (20, 7))

plt.subplot (1,3,1)
x = np.linspace (-2, 2, 400)
y_exp = np.exp(x)
plt.plot(x, y_exp)
plt.title('Експоненціальна функція')

plt.subplot(1, 3, 2)
x_positive = np.linspace(0.1, 2, 400)
y_log = np.log(x_positive)
plt.plot(x_positive, y_log)
plt.title('Логарифмічна функція')


plt.subplot (1, 3, 3)
x = np.linspace (-2, 2, 400)
y_sin_mod = np.sin(x) + x
plt.plot(x, y_sin_mod)
plt.title('Модифікована синусоїда')
# Out:
# Text(0.5, 1.0, 'Модифікована синусоїда')

# %% [markdown]
# 4. Модифікація і довершення графіку.
#   4.1. Для кожної панелі встановіть назву графіка та підписи до осей х та у (можна так і назвати `x` та формула функції).
#   4.2. Використайте різні кольори для кожного графіка.

# %%
plt.figure (figsize = (20, 7))

plt.subplot (1,3,1)
x = np.linspace (-2, 2, 400)
y_exp = np.exp(x)
plt.plot(x, y_exp, color ="green")
plt.title('Експоненціальна функція')
plt.xlabel ("x")
plt.ylabel ("y")

plt.subplot(1, 3, 2)
x_positive = np.linspace(0.1, 2, 400)
y_log = np.log(x_positive)
plt.plot(x_positive, y_log, color ="yellow")
plt.title('Логарифмічна функція')
plt.xlabel ("x")
plt.ylabel ("y")


plt.subplot (1, 3, 3)
x = np.linspace (-2, 2, 400)
y_sin_mod = np.sin(x) + x
plt.plot(x, y_sin_mod, color ="red")
plt.title('Модифікована синусоїда')
plt.xlabel ("x")
plt.ylabel ("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# 5. А тепер зобразіть ті самі 3 трафіки тих самих кольорів тільки на одному графіку. Визначіть назву кожної з ліній для легенди та обовʼязково відобразіть легенду.

# %%
plt.plot (x, y_exp, color ="green", label = 'Експоненціальна функція')
plt.plot (x_positive, y_log, color ="yellow", label = 'Логарифмічна функція')
plt.plot (x, y_sin_mod, color ="red", label = 'Модифікована синусоїда')
plt.legend ();

# %% [markdown]
# 6. Напишіть код аби зберегти графік з попереднього завдання у файл з назвою `my_figure.png` і виконайте код нижче аби зчитати фігуру з файлу назад в ноутбук аби переконатись, що графік зберігся як треба.

# %%
plt.plot (x, y_exp, color ="green", label = 'Експоненціальна функція')
plt.plot (x_positive, y_log, color ="yellow", label = 'Логарифмічна функція')
plt.plot (x, y_sin_mod, color ="red", label = 'Модифікована синусоїда')
plt.legend ();
plt.savefig('my_figure.png', dpi = 300)

# %%
import os
os.listdir ()
# Out:
# ['.ipynb_checkpoints',
#  '2_1_Функціїї_Основи (1).ipynb',
#  '2_2_Функції_Прововження.ipynb',
#  '2_3_Винятки_.ipynb',
#  '2_4_Класи_.ipynb',
#  'hw_1_1_1_1_1_2_Cинтаксис_Python.ipynb',
#  'hw_1_1_3_Основи_роботи_з_рядками_та_математичні_операції_.ipynb',
#  'hw_1_2_1_Списки.ipynb',
#  'hw_1_2_3_Словники,_набори,_кортежі.ipynb',
#  'hw_1_2_4_If_else.ipynb',
#  'hw_1_3_1_1_3_2_Цикл_for.ipynb',
#  'hw_1_3_3_Comprehensions.ipynb',
#  'hw_1_3_4_Цикл_while.ipynb',
#  'hw_3_1_Введення_у_Pandas_та_NumPy_.ipynb',
#  'hw_3_2_Основи_роботи_з_даними_у_Pandas.ipynb',
#  'hw_3_3_Розширені_методи_обробки_даних_у_Pandas_.ipynb',
#  'hw_3_4_apply,_groupby,_pivot_table.ipynb',
#  'hw_4_1_Базові_візуалізації.ipynb',
#  'hw_4_2_Базові_візуалізації_Продовження.ipynb',
#  'My first trial with python.ipynb',
#  'my_figure.png',
#  'supermarket_sales_enriched.csv']

# %%
from IPython.display import Image
Image('my_figure.png')
